# %%
from QCloud import *
import gymnasium as gym
from stable_baselines3 import PPO  # Or SAC / TD3, as desired
from stable_baselines3.common.env_checker import check_env

PRINTLOG = False
ibm_strasbourg = IBM_Strasbourg(env=None, name="ibm_strasbourg", cali_filepath='QCloud/calibration/03_2025/ibm_strasbourg_calibrations_2025-03-29T05_16_26Z.csv', printlog = PRINTLOG)
ibm_brussels = IBM_Brussels(env=None, name="ibm_brussels", cali_filepath='QCloud/calibration/03_2025/ibm_brussels_calibrations_2025-03-30T02_20_13Z.csv', printlog = PRINTLOG)
ibm_kyiv = IBM_Kyiv(env=None, name="ibm_kyiv", cali_filepath='QCloud/calibration/03_2025/ibm_kyiv_calibrations_2025-03-30T02_24_45Z.csv', printlog = PRINTLOG)
ibm_quebec = IBM_Quebec(env=None, name="ibm_quebec", cali_filepath='QCloud/calibration/03_2025/ibm_quebec_calibrations_2025-03-30T02_51_33Z.csv', printlog = PRINTLOG)
ibm_kawasaki = IBM_Kawasaki(env=None, name="ibm_kawasaki", cali_filepath='QCloud/calibration/03_2025/ibm_kawasaki_calibrations_2025-03-30T03_15_05Z.csv', printlog = PRINTLOG)

devices = [ibm_strasbourg, ibm_brussels, ibm_kyiv, ibm_quebec, ibm_kawasaki]

# (Assume 'devices' is a list of device objects and 'job_records_manager' is defined.)
gymenv = QCloudGymEnv(devices, job_records_manager, printlog=True)

# Check that the environment follows Gymnasium's interface.
check_env(gymenv)

# Create a PPO agent with a simple multi-layer perceptron policy.
model = PPO("MlpPolicy", gymenv, verbose=1)

# Train the agent over many timesteps.
model.learn(total_timesteps=10000)

# Save the trained model.
model.save("qcloud_ppo_model")
# Out:
# /Users/wolfwalker/anaconda3/lib/python3.10/site-packages/stable_baselines3/common/env_checker.py:421: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf. https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.343    |
# | time/              |          |
# |    fps             | 5614     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.402       |
# | time/                   |             |
# |    fps                  | 3717        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.086666964 |
# |    clip_fraction        | 0.583       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.07       |
# |    explained_variance   | -0.145      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0948     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.11       |
# |    std                  | 0.993       |
# |    value_loss           | 0.0246      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.452      |
# | time/                   |            |
# |    fps                  | 3364       |
# |    iterations           | 3          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.08986856 |
# |    clip_fraction        | 0.612      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.98      |
# |    explained_variance   | -0.00496   |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.113     |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.118     |
# |    std                  | 0.967      |
# |    value_loss           | 0.0241     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.499      |
# | time/                   |            |
# |    fps                  | 3248       |
# |    iterations           | 4          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.07969242 |
# |    clip_fraction        | 0.597      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.82      |
# |    explained_variance   | 0.00292    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.107     |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.118     |
# |    std                  | 0.934      |
# |    value_loss           | 0.023      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.55       |
# | time/                   |            |
# |    fps                  | 3133       |
# |    iterations           | 5          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.07502706 |
# |    clip_fraction        | 0.553      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.59      |
# |    explained_variance   | 0.00286    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.118     |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.116     |
# |    std                  | 0.888      |
# |    value_loss           | 0.0217     |
# ----------------------------------------

# %%
from stable_baselines3.common.callbacks import BaseCallback

class SaveTrainingStatsCallback(BaseCallback):
    def __init__(self, verbose=0):
        super().__init__(verbose)
        self.rewards = []
        self.entropies = []
        
    def _on_step(self) -> bool:
        # Collect reward and entropy loss
        reward = np.mean(self.locals["rewards"])
        entropy = float(self.model.logger.name_to_value["train/entropy_loss"])
        
        self.rewards.append(reward)
        self.entropies.append(entropy)
        return True

# Create callback
stats_callback = SaveTrainingStatsCallback()

# Train with callback
model = PPO("MlpPolicy", gymenv, verbose=1)
model.learn(total_timesteps=30000, callback=stats_callback)

# Plot after training
import matplotlib.pyplot as plt

plt.plot(stats_callback.rewards, label="Reward")
plt.plot(stats_callback.entropies, label="Entropy Loss")
plt.legend()
plt.xlabel("Training Step")
plt.title("Training Progress")
plt.show()

# %%
from QCloud import *
import gymnasium as gym
from stable_baselines3 import PPO  # Or SAC / TD3, as desired
from stable_baselines3.common.env_checker import check_env

PRINTLOG = False
ibm_strasbourg = IBM_Strasbourg(env=None, name="ibm_strasbourg", cali_filepath='QCloud/calibration/03_2025/ibm_strasbourg_calibrations_2025-03-29T05_16_26Z.csv', printlog = PRINTLOG)
ibm_brussels = IBM_Brussels(env=None, name="ibm_brussels", cali_filepath='QCloud/calibration/03_2025/ibm_brussels_calibrations_2025-03-30T02_20_13Z.csv', printlog = PRINTLOG)
ibm_kyiv = IBM_Kyiv(env=None, name="ibm_kyiv", cali_filepath='QCloud/calibration/03_2025/ibm_kyiv_calibrations_2025-03-30T02_24_45Z.csv', printlog = PRINTLOG)
ibm_quebec = IBM_Quebec(env=None, name="ibm_quebec", cali_filepath='QCloud/calibration/03_2025/ibm_quebec_calibrations_2025-03-30T02_51_33Z.csv', printlog = PRINTLOG)
ibm_kawasaki = IBM_Kawasaki(env=None, name="ibm_kawasaki", cali_filepath='QCloud/calibration/03_2025/ibm_kawasaki_calibrations_2025-03-30T03_15_05Z.csv', printlog = PRINTLOG)

devices = [ibm_strasbourg, ibm_brussels, ibm_kyiv, ibm_quebec, ibm_kawasaki]

# (Assume 'devices' is a list of device objects and 'job_records_manager' is defined.)
gymenv = QCloudGymEnv(devices, job_records_manager, printlog=True)

# Check that the environment follows Gymnasium's interface.
check_env(gymenv)

# Create a PPO agent with a simple multi-layer perceptron policy.
model = PPO("MlpPolicy", gymenv, verbose=1)

# Train the agent over many timesteps.
model.learn(total_timesteps=100000)

# Save the trained model.
model.save("qcloud_ppo_model-new")
# Out:
# /Users/wolfwalker/anaconda3/lib/python3.10/site-packages/stable_baselines3/common/env_checker.py:421: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf. https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1        |
# |    ep_rew_mean     | 0.349    |
# | time/              |          |
# |    fps             | 5829     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.421       |
# | time/                   |             |
# |    fps                  | 3811        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.101985544 |
# |    clip_fraction        | 0.615       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -7.07       |
# |    explained_variance   | -0.027      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.108      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.117      |
# |    std                  | 0.993       |
# |    value_loss           | 0.0247      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.46       |
# | time/                   |            |
# |    fps                  | 3491       |
# |    iterations           | 3          |
# |    time_elapsed         | 1          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.08917905 |
# |    clip_fraction        | 0.608      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.98      |
# |    explained_variance   | 0.00831    |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.11      |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.119     |
# |    std                  | 0.967      |
# |    value_loss           | 0.0243     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.514      |
# | time/                   |            |
# |    fps                  | 3366       |
# |    iterations           | 4          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.08919282 |
# |    clip_fraction        | 0.591      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.8       |
# |    explained_variance   | 0.0103     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.104     |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.118     |
# |    std                  | 0.928      |
# |    value_loss           | 0.0232     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.546      |
# | time/                   |            |
# |    fps                  | 3298       |
# |    iterations           | 5          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.07261713 |
# |    clip_fraction        | 0.559      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.57      |
# |    explained_variance   | 0.0204     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.111     |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.115     |
# |    std                  | 0.883      |
# |    value_loss           | 0.0206     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.574      |
# | time/                   |            |
# |    fps                  | 3255       |
# |    iterations           | 6          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.08128384 |
# |    clip_fraction        | 0.546      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6.29      |
# |    explained_variance   | 0.0298     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.104     |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.114     |
# |    std                  | 0.832      |
# |    value_loss           | 0.0167     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.593      |
# | time/                   |            |
# |    fps                  | 3215       |
# |    iterations           | 7          |
# |    time_elapsed         | 4          |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.06450037 |
# |    clip_fraction        | 0.515      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -6         |
# |    explained_variance   | 0.0223     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0876    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.11      |
# |    std                  | 0.786      |
# |    value_loss           | 0.0145     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.643      |
# | time/                   |            |
# |    fps                  | 3194       |
# |    iterations           | 8          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.05279142 |
# |    clip_fraction        | 0.481      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -5.71      |
# |    explained_variance   | 0.0327     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.103     |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.104     |
# |    std                  | 0.742      |
# |    value_loss           | 0.0119     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.661       |
# | time/                   |             |
# |    fps                  | 3169        |
# |    iterations           | 9           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.044472672 |
# |    clip_fraction        | 0.429       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -5.42       |
# |    explained_variance   | 0.0543      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.121      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0941     |
# |    std                  | 0.7         |
# |    value_loss           | 0.00897     |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1         |
# |    ep_rew_mean          | 0.668     |
# | time/                   |           |
# |    fps                  | 3146      |
# |    iterations           | 10        |
# |    time_elapsed         | 6         |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0380036 |
# |    clip_fraction        | 0.399     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -5.15     |
# |    explained_variance   | 0.0673    |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0961   |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -0.0844   |
# |    std                  | 0.664     |
# |    value_loss           | 0.00698   |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.685      |
# | time/                   |            |
# |    fps                  | 3137       |
# |    iterations           | 11         |
# |    time_elapsed         | 7          |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.03317967 |
# |    clip_fraction        | 0.366      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.88      |
# |    explained_variance   | 0.0875     |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0779    |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0733    |
# |    std                  | 0.63       |
# |    value_loss           | 0.00538    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.693       |
# | time/                   |             |
# |    fps                  | 3129        |
# |    iterations           | 12          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.025262428 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.64       |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0611     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0636     |
# |    std                  | 0.601       |
# |    value_loss           | 0.00396     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.693       |
# | time/                   |             |
# |    fps                  | 3117        |
# |    iterations           | 13          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.025146969 |
# |    clip_fraction        | 0.292       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.41       |
# |    explained_variance   | 0.157       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0745     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0551     |
# |    std                  | 0.575       |
# |    value_loss           | 0.00306     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.707       |
# | time/                   |             |
# |    fps                  | 3111        |
# |    iterations           | 14          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.017708441 |
# |    clip_fraction        | 0.275       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0366     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0466     |
# |    std                  | 0.553       |
# |    value_loss           | 0.00249     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.702      |
# | time/                   |            |
# |    fps                  | 3104       |
# |    iterations           | 15         |
# |    time_elapsed         | 9          |
# |    total_timesteps      | 30720      |
# | train/                  |            |
# |    approx_kl            | 0.01679314 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.03      |
# |    explained_variance   | 0.292      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0434    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0363    |
# |    std                  | 0.534      |
# |    value_loss           | 0.00158    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.712       |
# | time/                   |             |
# |    fps                  | 3101        |
# |    iterations           | 16          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015785404 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.31        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0526     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0366     |
# |    std                  | 0.516       |
# |    value_loss           | 0.00151     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.705       |
# | time/                   |             |
# |    fps                  | 3093        |
# |    iterations           | 17          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011760689 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.387       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0432     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0281     |
# |    std                  | 0.501       |
# |    value_loss           | 0.00116     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.7         |
# | time/                   |             |
# |    fps                  | 3085        |
# |    iterations           | 18          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.011114416 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.473       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0334     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0205     |
# |    std                  | 0.488       |
# |    value_loss           | 0.000867    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.714       |
# | time/                   |             |
# |    fps                  | 3081        |
# |    iterations           | 19          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.011638908 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.546       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0225     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0176     |
# |    std                  | 0.479       |
# |    value_loss           | 0.000642    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.71        |
# | time/                   |             |
# |    fps                  | 3078        |
# |    iterations           | 20          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.011089146 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.36       |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00537    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.47        |
# |    value_loss           | 0.000553    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.708        |
# | time/                   |              |
# |    fps                  | 3076         |
# |    iterations           | 21           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0067469003 |
# |    clip_fraction        | 0.128        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.27        |
# |    explained_variance   | 0.697        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0167      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00572     |
# |    std                  | 0.462        |
# |    value_loss           | 0.000365     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.711        |
# | time/                   |              |
# |    fps                  | 3073         |
# |    iterations           | 22           |
# |    time_elapsed         | 14           |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0107056685 |
# |    clip_fraction        | 0.115        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.19        |
# |    explained_variance   | 0.67         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0132      |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00506     |
# |    std                  | 0.454        |
# |    value_loss           | 0.000395     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.714       |
# | time/                   |             |
# |    fps                  | 3070        |
# |    iterations           | 23          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.008858668 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000461    |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00463    |
# |    std                  | 0.447       |
# |    value_loss           | 0.000381    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.706       |
# | time/                   |             |
# |    fps                  | 3068        |
# |    iterations           | 24          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008833572 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.697       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0179     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00272    |
# |    std                  | 0.439       |
# |    value_loss           | 0.000386    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.706        |
# | time/                   |              |
# |    fps                  | 3061         |
# |    iterations           | 25           |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0095056705 |
# |    clip_fraction        | 0.113        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.95        |
# |    explained_variance   | 0.756        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0102      |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00178     |
# |    std                  | 0.436        |
# |    value_loss           | 0.00029      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.71        |
# | time/                   |             |
# |    fps                  | 3053        |
# |    iterations           | 26          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009706788 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0323      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.000361   |
# |    std                  | 0.428       |
# |    value_loss           | 0.000255    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.712       |
# | time/                   |             |
# |    fps                  | 3044        |
# |    iterations           | 27          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010979483 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.83       |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0114     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000968   |
# |    std                  | 0.425       |
# |    value_loss           | 0.000274    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.712       |
# | time/                   |             |
# |    fps                  | 3039        |
# |    iterations           | 28          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.007952177 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.009       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00372    |
# |    std                  | 0.418       |
# |    value_loss           | 0.000318    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.704      |
# | time/                   |            |
# |    fps                  | 3034       |
# |    iterations           | 29         |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.00880699 |
# |    clip_fraction        | 0.116      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.71      |
# |    explained_variance   | 0.819      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0185    |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -5.62e-05  |
# |    std                  | 0.416      |
# |    value_loss           | 0.000215   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.711        |
# | time/                   |              |
# |    fps                  | 3030         |
# |    iterations           | 30           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0070279203 |
# |    clip_fraction        | 0.107        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.69        |
# |    explained_variance   | 0.841        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00915     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | 0.000522     |
# |    std                  | 0.414        |
# |    value_loss           | 0.000191     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.708       |
# | time/                   |             |
# |    fps                  | 3025        |
# |    iterations           | 31          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.010138316 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00586     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | 0.00125     |
# |    std                  | 0.409       |
# |    value_loss           | 0.000211    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.707        |
# | time/                   |              |
# |    fps                  | 3021         |
# |    iterations           | 32           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0072092023 |
# |    clip_fraction        | 0.118        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.6         |
# |    explained_variance   | 0.837        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00449     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0016      |
# |    std                  | 0.405        |
# |    value_loss           | 0.000186     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.711       |
# | time/                   |             |
# |    fps                  | 3020        |
# |    iterations           | 33          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.006472627 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.841       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00541     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | 0.00133     |
# |    std                  | 0.405       |
# |    value_loss           | 0.000195    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.709       |
# | time/                   |             |
# |    fps                  | 3021        |
# |    iterations           | 34          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.009809649 |
# |    clip_fraction        | 0.0884      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0408      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.000273   |
# |    std                  | 0.402       |
# |    value_loss           | 0.000254    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.712       |
# | time/                   |             |
# |    fps                  | 3020        |
# |    iterations           | 35          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.009366995 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | 0.808       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0163      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00188    |
# |    std                  | 0.397       |
# |    value_loss           | 0.000274    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.711       |
# | time/                   |             |
# |    fps                  | 3021        |
# |    iterations           | 36          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.010871491 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.48       |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00281    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | 0.00101     |
# |    std                  | 0.399       |
# |    value_loss           | 0.000165    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1          |
# |    ep_rew_mean          | 0.713      |
# | time/                   |            |
# |    fps                  | 3019       |
# |    iterations           | 37         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.01133533 |
# |    clip_fraction        | 0.115      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.48      |
# |    explained_variance   | 0.822      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0298     |
# |    n_updates            | 360        |
# |    policy_gradient_loss | 0.00208    |
# |    std                  | 0.397      |
# |    value_loss           | 0.000188   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.711       |
# | time/                   |             |
# |    fps                  | 3019        |
# |    iterations           | 38          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.012447564 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0323     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00356    |
# |    std                  | 0.393       |
# |    value_loss           | 0.000155    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.709       |
# | time/                   |             |
# |    fps                  | 3019        |
# |    iterations           | 39          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008469211 |
# |    clip_fraction        | 0.137       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000365    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | 0.00209     |
# |    std                  | 0.392       |
# |    value_loss           | 0.000134    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1            |
# |    ep_rew_mean          | 0.718        |
# | time/                   |              |
# |    fps                  | 3019         |
# |    iterations           | 40           |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0104982015 |
# |    clip_fraction        | 0.129        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.38        |
# |    explained_variance   | 0.819        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0205       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | 0.00192      |
# |    std                  | 0.388        |
# |    value_loss           | 0.000202     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.708       |
# | time/                   |             |
# |    fps                  | 3020        |
# |    iterations           | 41          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008938411 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.33       |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0123      |
# |    n_updates            | 400         |
# |    policy_gradient_loss | 0.00398     |
# |    std                  | 0.384       |
# |    value_loss           | 0.000186    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.705       |
# | time/                   |             |
# |    fps                  | 3019        |
# |    iterations           | 42          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.006514316 |
# |    clip_fraction        | 0.124       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000488   |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00151     |
# |    std                  | 0.385       |
# |    value_loss           | 0.000136    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.71        |
# | time/                   |             |
# |    fps                  | 3019        |
# |    iterations           | 43          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.007119742 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.807       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -8.91e-05   |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.00257     |
# |    std                  | 0.381       |
# |    value_loss           | 0.000227    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.716       |
# | time/                   |             |
# |    fps                  | 3019        |
# |    iterations           | 44          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.009940334 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0126      |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00224     |
# |    std                  | 0.382       |
# |    value_loss           | 0.000137    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.711       |
# | time/                   |             |
# |    fps                  | 3019        |
# |    iterations           | 45          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.011106694 |
# |    clip_fraction        | 0.123       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00616    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | 0.000166    |
# |    std                  | 0.381       |
# |    value_loss           | 0.000138    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.706       |
# | time/                   |             |
# |    fps                  | 3019        |
# |    iterations           | 46          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.009250067 |
# |    clip_fraction        | 0.0968      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 0.838       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00658    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | 0.0033      |
# |    std                  | 0.379       |
# |    value_loss           | 0.000179    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.707       |
# | time/                   |             |
# |    fps                  | 3016        |
# |    iterations           | 47          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.007213731 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0184     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | 0.00087     |
# |    std                  | 0.376       |
# |    value_loss           | 0.00015     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.717       |
# | time/                   |             |
# |    fps                  | 3016        |
# |    iterations           | 48          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.009196071 |
# |    clip_fraction        | 0.144       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.18       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00733    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00238    |
# |    std                  | 0.373       |
# |    value_loss           | 0.000171    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1           |
# |    ep_rew_mean          | 0.712       |
# | time/                   |             |
# |    fps                  | 3017        |
# |    iterations           | 49          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.011189824 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.17       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00905    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | 0.00242     |
# |    std                  | 0.374       |
# |    value_loss           | 0.000126    |
# -----------------------------------------

# %%
import matplotlib.pyplot as plt

FONTSIZE = 14

# Example data (replace with your actual data)
training_steps = [
    2048, 4096, 6144, 8192, 10240, 12288, 14336, 16384, 18432, 20480,
    22528, 24576, 26624, 28672, 30720, 32768, 34816, 36864, 38912, 40960,
    43008, 45056, 47104, 49152, 51200, 53248, 55296, 57344, 59392, 61440,
    63488, 65536, 67584, 69632, 71680, 73728, 75776, 77824, 79872, 81920,
    83968, 86016, 88064, 90112, 92160, 94208, 96256, 98304, 100352
]

rewards = [
    0.352, 0.393, 0.460, 0.533, 0.546, 0.580, 0.619, 0.625, 0.654, 0.675,
    0.680, 0.695, 0.691, 0.702, 0.698, 0.706, 0.705, 0.703, 0.710, 0.707,
    0.709, 0.714, 0.711, 0.708, 0.706, 0.710, 0.712, 0.712, 0.704, 0.711,
    0.707, 0.707, 0.711, 0.709, 0.712, 0.711, 0.711, 0.712, 0.711, 0.712,
    0.708, 0.705, 0.710, 0.716, 0.713, 0.706, 0.707, 0.717, 0.712
]

entropy_losses = [
    -7.07, -7.07, -6.98, -6.82, -6.59, -6.33, -6.05, -5.74, -5.46, -5.19,
    -4.93, -4.68, -4.47, -4.27, -4.09, -3.92, -3.77, -3.63, -3.51, -3.4,
    -3.3, -3.21, -3.13, -3.05, -2.95, -2.88, -2.83, -2.76, -2.71, -2.67,
    -2.64, -2.62, -2.6, -2.54, -2.49, -2.44, -2.4, -2.36, -2.34, -2.31,
    -2.27, -2.24, -2.22, -2.21, -2.18, -2.16, -2.14, -2.13, -2.11
]

# Plotting
fig, ax1 = plt.subplots(figsize=(6.5, 4.5))

# Left y-axis: Average Episode Reward
color = 'tab:blue'
ax1.set_xlabel('Training Steps', fontsize=FONTSIZE)
ax1.set_ylabel('Average Episode Reward', color=color, fontsize=FONTSIZE)
ln1 = ax1.plot(training_steps, rewards, color=color, marker='o', label='Average Episode Reward')
ax1.tick_params(axis='y', labelcolor=color, labelsize = FONTSIZE)
ax1.tick_params(axis='x', labelsize=FONTSIZE)
ax1.grid(True, linestyle='--', linewidth=0.5)

# Right y-axis: Entropy Loss
ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Entropy Loss', color=color, fontsize=FONTSIZE)
ln2 = ax2.plot(training_steps, entropy_losses, color=color, marker='d', label='Entropy Loss')
ax2.tick_params(axis='y', labelcolor=color, labelsize = FONTSIZE)
lines = ln1 + ln2
labels = [l.get_label() for l in lines]
ax1.legend(lines, labels, loc='lower right', fontsize=FONTSIZE)
# Title and layout
# plt.title('PPO Training Progress: Average Episode Reward vs Entropy Loss')
fig.tight_layout()

# Show the plot
plt.show()
